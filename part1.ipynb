# %% [markdown]
# # Final Project Part 1 - Proposal
#
# For my final project, I will be using a dataset of email responders to journal article submission campaigns from Q1 2019
#
# ## Hypothesis, Assumptions, and Goals
#
# I am looking to use this data to figure out which variables may affect the recipients’ engagements with email campaigns of two differing academic disciplines. My assumption is that features surrounding previous article submission, recipient supplied interest codes matches, prior engagement with similar campaigns, and individual features may all affect the engagement
#
# This information could help with more precise campaign targeting, with the aim of raising engagement and reducing of ‘overmailing’ of unlikely engagement prospects, ultimately raising article submission revenue and contact retention. I want to use this existing data to create a model that will predict email campaign engagement in several key disciplines
#
# ## Risks and Limitations
#
# The main limitation of using this dataset is that it only includes recent data, due to the sheer scale of data available when looking over a larger period. However the nature of this specific part of the business (journal article submission) has seen sea-changes in the last 18 months, so using only recent data is likely to be a better reflection of current trends for use in the working model
#
# ## The Dataset
#
# As shown below, this dataset includes the campaign recipients, campaign metadata, indicators for academic contacts, china based contacts, prior article submission, recent article submission, interest code matches (broad and precise), prior engagement and recent engagement (and their value counts) along with the key target variable of engagement (campaign open) along with active engagement (click) and disengagement (unsubscribes) which could potentially be combined into an 'engagement type' for the key target variable. This data was drawn from Q1 campaigning data, from which a random subset has been drawn:

# %%
import pandas as pd 

engagement = pd.read_csv('engagement.csv')

engagement.head(5)
# Out:
#                       email  launch_id cellcode product_featured  \
# 0        0617331@zju.edu.cn      76158       ST             L243
# 1         07248@buaa.edu.cn      76158    HOUSE             L243
# 2       0801sky@hanmail.net      91266       ST             L104
# 3         0jj00@hanmail.net      91266       ST             L104
# 4  10211220014@fudan.edu.cn      63226    HOUSE             L104
#
#   product_discipline         product_subject date_launched  month  \
# 0        Engineering  Mechanical Engineering     2/12/2019      2
# 1        Engineering  Mechanical Engineering     2/12/2019      2
# 2  Clinical Medicine       Clinical Medicine     3/28/2019      3
# 3  Clinical Medicine       Clinical Medicine     3/28/2019      3
# 4  Clinical Medicine       Clinical Medicine      1/2/2019      1
#
#    is_academic_email  is_china_recipient      ...       recent_responses  \
# 0                  1                   1      ...                      0
# ...

# %%
engagement_subset = engagement.sample(frac=.25)

# %%
# checking so see values counts by various features to verify a representative split of full data

# engagement_subset.loc[:, 'product_discipline'].value_counts()
# engagement_subset.loc[:, 'month'].value_counts()
# engagement_subset.loc[:, 'is_china_recipient'].value_counts()
# engagement_subset.loc[:, 'is_submitter_discipline'].value_counts()
# engagement_subset.loc[:, 'has_discipline_code_match'].value_counts()

# %%
engagement_subset.to_csv (r'C:\Users\WTabraham\OneDrive - SAGE Publishing\Desktop\general_assembly\final_project\engagement_subset.csv')
